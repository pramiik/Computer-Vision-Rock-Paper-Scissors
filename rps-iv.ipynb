# %%
import cv2
from keras.models import load_model
import numpy as np
import random
import time
model = load_model('keras_model.h5')
cap = cv2.VideoCapture(0)
data = np.ndarray(shape=(1, 224, 224, 3), dtype=np.float32)

game_options= [ "rock", "paper", "scissors"]

player_points =int()
computer_points =int()
game = int()


#t= time.time()
#count =5
'''
def startkey():
    global countdown

    if cv2.waitKey(1) & 0xFF == ord('r'):
        countdown = timer +3
    elif cv2.waitKey(1)& 0xFF ==ord('p'):
        countdown = timer + 3
        display()


'''

def computer():
    global computer_input

    computer_input = random.choice(game_options)

    cv2.putText(frame, computer_input, (392, 363), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255),3,cv2.LINE_4)


    return computer_input

def player():
    computer()
    global player_input
    global timer
    global player_points
    global computer_points
    global game
    global prediction

    cv2.putText(frame,'Player vs Computer', (54,426),cv2.FONT_HERSHEY_SIMPLEX, 1.7, (0, 0, 0), 5, cv2.LINE_4)
    cv2.putText (frame,'number of games: ', (25, 25), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255),5)

    cv2.putText(frame, str(int(timer)), (52,457),cv2.FONT_HERSHEY_SIMPLEX, 1.7, (0, 0, 0), 5, cv2.LINE_4)
    
    rock1 = prediction[0][0] > 0.7
    paper1 = prediction[0][1] > 0.7
    scissors1 = prediction[0][2] > 0.7
    nothing1 = prediction[0][3] > 0.7 

    prediction1=[rock1, paper1, scissors1, nothing1]


    if prediction1[0] == True:
        player_choice = "rock1"
    elif prediction1[1] == True:
        player_choice = "paper1"
    elif prediction1[2] == True:
        player_choice = "scissors1"
    else:
       player_choice = "Try Again"    

    player_input = player_choice

    cv2.putText (frame,player_input, (75, 363), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255),3)



    return player_input and computer_input




def gameplay():
 

    global computer_input
    global player_input
    global wins
    global insert
    global ex
    global player_points
    global computer_points
    global game
    global timer



    wins = str()
    finalwins = str()



    if (player_input =="paper1" and computer_input == "rock")  or (player_input =="rock1" and computer_input == "scissors")  or (player_input == "scissors1" and computer_input == "paper") :
        print("player wins")    
        wins="player"
        player_points +=1
        game +=1
        cv2.putText (frame, "player wins this round", (32, 255), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 0),3)

    elif (player_input == "rock1" and computer_input == "rock")  or (player_input =="paper1" and computer_input== "paper")  or (player_input == "scissors1" and computer_input ==  "scissors") :
        print("Draw")

        game +=1

        cv2.putText (frame, "draw", (32, 255), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 0),3)

    elif (player_input == "rock1" and computer_input ==  "paper")  or (player_input =="paper1" and computer_input== "scissors")  or (player_input == "scissors1" and computer_input == "rock") :
        print("computer wins")
        wins="computer"
        computer_points +=1
        game +=1
        cv2.putText (frame, "computer wins this round", (32, 255), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 0),3)
        

    else :
        print('try again')





    if player_points>3:
        #finalwins="Player"
        #insert=True
        cv2.putText (frame,("player wins this game! Game Over"),(25,200), cv2.FONT_HERSHEY_SIMPLEX,1,(0,0,0),2)
        time.sleep(10)

    elif computer_points>3:
        cv2.putText (frame,(" computer this game! Game Over"),(25,200), cv2.FONT_HERSHEY_SIMPLEX,1,(0,0,0),2)
        time.sleep(10)

        #finalwins="computer"
        #insert =True
        #ex=True
    
 


t = time.time()
while True:
    
    ret, frame = cap.read()

    #frame = frame[32:, 188:]
    
    resized_frame = cv2.resize(frame, (224, 224), interpolation = cv2.INTER_AREA)
    image_np = np.array(resized_frame)
    normalized_image = (image_np.astype(np.float32) / 127.0) - 1 # Normalize the image
    data[0] = normalized_image
    prediction = model.predict(data)

    cv2.putText(frame,'Player vs Computer', (54,426),cv2.FONT_HERSHEY_SIMPLEX, 1.7, (0, 0, 0), 5, cv2.LINE_4)
    cv2.putText (frame,'number of games: ', (25, 25), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255),5)
    ret, frame = cap.read()
    t_elapsed = time.time() - t
    timer = int(5 - round(t_elapsed, 0))

    player()

    if timer<=0:
            
        gameplay()
        
        
        cv2.putText(frame,'Player vs Computer', (54,426),cv2.FONT_HERSHEY_SIMPLEX, 1.7, (0, 0, 0), 5, cv2.LINE_4)
        cv2.putText (frame,'number of games: ', (25, 25), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255),5)
        
        cv2.putText(frame, computer_input, (392, 363), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255),3,cv2.LINE_4)

        cv2.putText(frame, str(int(timer)), (117,190),cv2.FONT_HERSHEY_SIMPLEX, 1.7, (0, 0, 0), 5, cv2.LINE_4)
        
        cv2.putText(frame, str(player_points), (117, 471), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255),3)

        cv2.putText (frame, str(computer_points), (445, 471), cv2. FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255),3)
        cv2.putText (frame, str(game), (332, 32), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 0),3)

        
        t= time.time()

        time.sleep(2)
            

    




    

    cv2.imshow('frame', frame)
    
    
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
# Out:
# 2022-02-13 22:28:36.651550: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/pramika/miniconda3/envs/rps/lib/python3.9/site-packages/cv2/../../lib64:
# 2022-02-13 22:28:36.651596: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2022-02-13 22:28:39.047545: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/pramika/miniconda3/envs/rps/lib/python3.9/site-packages/cv2/../../lib64:
# 2022-02-13 22:28:39.047607: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-02-13 22:28:39.047640: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (pramika-HP-ENVY-x360-Convertible-13-ar0xxx): /proc/driver/nvidia/version does not exist
# 2022-02-13 22:28:39.048064: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# Draw
# try again
# try again
# computer wins
# try again
# Draw
# player wins
# computer wins
# player wins
# player wins
# try again
# try again
# try again
