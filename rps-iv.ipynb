# %%
import cv2
from keras.models import load_model
import numpy as np
import random
import time
model = load_model('keras_model.h5')

countdown = False
insert = False
ex = True
prt = False
pit = False
stop = False
t_0 = time.time()
timer = 0

cap = cv2.VideoCapture(0)
data = np.ndarray(shape=(1, 224, 224, 3), dtype=np.float32)

final_time = 5

game_options= [ "rock", "paper", "scissors"]

player_points =int()
computer_points =int()
game = int()

wins = str()
finalwins = str()
ds = str()
computer_input = str()
player_input = str()



def computer():
    global computer_input
    global frame

    computer_input = random.choice(game_options)

    cv2.putText(frame, computer_input, (392, 363), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255),3,cv2.LINE_4)
    cv2.imshow('frame', frame)


    return computer_input

def player():
    computer()
    global player_input
    global timer
    global player_points
    global computer_points
    global game
    global prediction
    global frame


    cv2.putText(frame,'Player vs Computer', (54,426),cv2.FONT_HERSHEY_SIMPLEX, 1.7, (0, 0, 0), 5, cv2.LINE_4)
    cv2.putText (frame,'number of games: ', (25, 25), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255),5)

    #cv2.putText(frame, str(int(timer)), (52,457),cv2.FONT_HERSHEY_SIMPLEX, 1.7, (0, 0, 0), 5, cv2.LINE_4)
    
    rock1 = prediction[0][0] > 0.7
    paper1 = prediction[0][1] > 0.7
    scissors1 = prediction[0][2] > 0.7
    nothing1 = prediction[0][3] > 0.7 

    prediction1=[rock1, paper1, scissors1, nothing1]


    if prediction1[0] == True:
        player_choice = "rock1"
    elif prediction1[1] == True:
        player_choice = "paper1"
    elif prediction1[2] == True:
        player_choice = "scissors1"
    else:
       player_choice = "Try Again"    

    player_input = player_choice

    cv2.putText (frame,player_input, (75, 363), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255),3)

    cv2.imshow('frame', frame)


    return player_input and computer_input



t = time.time()
#layer()
while True:
    
    ret, frame = cap.read()
    
    resized_frame = cv2.resize(frame, (224, 224), interpolation = cv2.INTER_AREA)
    image_np = np.array(resized_frame)
    normalized_image = (image_np.astype(np.float32) / 127.0) - 1 # Normalize the image
    data[0] = normalized_image
    prediction = model.predict(data)

    cv2.putText(frame,'Player vs Computer', (54,426),cv2.FONT_HERSHEY_SIMPLEX, 1.7, (0, 0, 0), 5, cv2.LINE_4)
    cv2.putText (frame,'number of games: ', (25, 25), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255),5)
    ret, frame = cap.read()
  

    if cv2.waitKey(33) == ord('a'):
        countdown =True
    
    if countdown == True:
        #gameplay()
        timer = time.time() - t_0
        player()
    else:
        t_0 = time.time()
        
    if timer >= 5:

        countdown = False 
        timer = 0

        if (player_input =="paper1" and computer_input == "rock")  or (player_input =="rock1" and computer_input == "scissors")  or (player_input == "scissors1" and computer_input == "paper") :
            print("player wins")    
            wins="player"
            player_points +=1
            game +=1
            next= True
            cv2.putText (frame, "player wins this round", (32, 255), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 0),3)

        elif (player_input == "rock1" and computer_input == "rock")  or (player_input =="paper1" and computer_input== "paper")  or (player_input == "scissors1" and computer_input ==  "scissors") :
            print("Draw")

            game +=1
            ds= "Draw"


            cv2.putText (frame, "draw", (32, 255), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 0),3)

        elif (player_input == "rock1" and computer_input ==  "paper")  or (player_input =="paper1" and computer_input== "scissors")  or (player_input == "scissors1" and computer_input == "rock") :
            print("computer wins")

            wins="computer"

            computer_points +=1
            Next = True
            game +=1
            cv2.putText (frame, "computer wins this round", (32, 255), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 0),3)
            

        else :
            print('try again')

        if next == True:
                    
            if player_points +1:
                cv2.putText (frame, "player wins this round", (32, 255), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 0),3)
                wins="player"
                ex = False
                next = False
                prt = True

            elif computer_points +1:
                cv2.putText (frame, "computer wins this round", (32, 255), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 0),3)
                wins="computer"
                ex = False
                next = False
                prt =True

            else:
                cv2.putText (frame, "draw", (32, 255), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 0),3)
                ds= "Draw"
                countdown = False
                timer = 0
                next = False
                ex = False
                prt = False
                pit =True
                
                


        if ex ==False:

            if player_points==3:

                cv2.putText (frame,("player wins this game! Game Over"),(25,200), cv2.FONT_HERSHEY_SIMPLEX,1,(0,0,0),2)
                insert = True

                finalwins = "Player"
                #time.sleep(10)
                countdown = False
                timer = 0
                stop =True
                


            elif computer_points==3:
                cv2.putText (frame,(" computer wins this game! Game Over"),(25,200), cv2.FONT_HERSHEY_SIMPLEX,1,(0,0,0),2)
                insert = True
                finalwins = "Computer"
                #time.sleep(10)
                countdown = False
                timer = 0
                stop =True
                

            else:
                timer = 0
                countdown = False
                next = False




    cv2.putText(frame, str(final_time - timer ), (100, 100), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 0), 2)

            
        
        
    cv2.putText(frame,'Player vs Computer', (54,426),cv2.FONT_HERSHEY_SIMPLEX, 1.7, (0, 0, 0), 5, cv2.LINE_4)
    cv2.putText (frame,'number of games: ', (25, 25), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255),5)
        
    cv2.putText(frame, str(player_points), (117, 471), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255),3)

    cv2.putText (frame, str(computer_points), (445, 471), cv2. FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255),3)
    cv2.putText (frame, str(game), (332, 32), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 0),3)

    cv2.putText (frame,player_input, (75, 363), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255),3)
    cv2.putText(frame, computer_input, (392, 363), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255),3,cv2.LINE_4)
    


    
    if prt == True:
        word = (wins) +"  " + "wins this round!"
        cv2.putText (frame, word, (32, 255), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 0),3)

    elif pit == True:

        letter = (ds) +"!" 
        cv2.putText (frame, letter, (32, 255), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 0),3)

    else:
        print("something went wrong :(")

    if insert == True:

        text = finalwins + "wins this game! GAME OVER!!"
        cv2.putText (frame,text,(25,200), cv2.FONT_HERSHEY_SIMPLEX,1,(0,0,0),2)

    else:
        print("something went wrong :(")

    if stop == True:

        cv2.putText (frame, "press button q to restart the game", (32, 145), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 0),3)
        
        if cv2.waitKey(1) & 0xFF == ord('q'):
            game = 0
            player_points = 0
            computer_points = 0
    
    else:
        print ("something went wrong with stop bool :(")





    cv2.imshow('frame', frame)
# Out:
# 2022-02-16 19:25:05.062710: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/pramika/miniconda3/envs/rps/lib/python3.9/site-packages/cv2/../../lib64:
# 2022-02-16 19:25:05.062760: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2022-02-16 19:25:08.128769: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/pramika/miniconda3/envs/rps/lib/python3.9/site-packages/cv2/../../lib64:
# 2022-02-16 19:25:08.128831: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-02-16 19:25:08.128869: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (pramika-HP-ENVY-x360-Convertible-13-ar0xxx): /proc/driver/nvidia/version does not exist
# 2022-02-16 19:25:08.129364: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# Draw
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# Draw
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# computer wins
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# computer wins
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# ...
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# try again
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# player wins
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# Draw
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# player wins
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_19106/1689834272.py in <module>
#     100     normalized_image = (image_np.astype(np.float32) / 127.0) - 1 # Normalize the image
#     101     data[0] = normalized_image
# --> 102     prediction = model.predict(data)
#     103
#     104     cv2.putText(frame,'Player vs Computer', (54,426),cv2.FONT_HERSHEY_SIMPLEX, 1.7, (0, 0, 0), 5, cv2.LINE_4)
#
# ~/miniconda3/envs/rps/lib/python3.9/site-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~/miniconda3/envs/rps/lib/python3.9/site-packages/keras/engine/training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1783       callbacks.on_predict_begin()
#    1784       batch_outputs = None
# -> 1785       for _, iterator in data_handler.enumerate_epochs():  # Single epoch.
#    1786         with data_handler.catch_stop_iteration():
#    1787           for step in data_handler.steps():
#
# ~/miniconda3/envs/rps/lib/python3.9/site-packages/keras/engine/data_adapter.py in enumerate_epochs(self)
#    1193     """Yields `(epoch, tf.data.Iterator)`."""
#    1194     with self._truncate_execution_to_epoch():
# -> 1195       data_iterator = iter(self._dataset)
#    1196       for epoch in range(self._initial_epoch, self._epochs):
#    1197         if self._insufficient_data:  # Set by `catch_stop_iteration`.
#
# ~/miniconda3/envs/rps/lib/python3.9/site-packages/tensorflow/python/data/ops/dataset_ops.py in __iter__(self)
#     488     if context.executing_eagerly() or ops.inside_function():
#     489       with ops.colocate_with(self._variant_tensor):
# --> 490         return iterator_ops.OwnedIterator(self)
#     491     else:
#     492       raise RuntimeError("`tf.data.Dataset` only supports Python-style "
#
# ~/miniconda3/envs/rps/lib/python3.9/site-packages/tensorflow/python/data/ops/iterator_ops.py in __init__(self, dataset, components, element_spec)
#     724             "When `dataset` is provided, `element_spec` and `components` must "
#     725             "not be specified.")
# --> 726       self._create_iterator(dataset)
#     727
#     728     self._get_next_call_count = 0
#
# ~/miniconda3/envs/rps/lib/python3.9/site-packages/tensorflow/python/data/ops/iterator_ops.py in _create_iterator(self, dataset)
#     749               output_types=self._flat_output_types,
#     750               output_shapes=self._flat_output_shapes))
# --> 751       gen_dataset_ops.make_iterator(ds_variant, self._iterator_resource)
#     752       # Delete the resource when this object is deleted
#     753       self._resource_deleter = IteratorResourceDeleter(
#
# ~/miniconda3/envs/rps/lib/python3.9/site-packages/tensorflow/python/ops/gen_dataset_ops.py in make_iterator(dataset, iterator, name)
#    3235   if tld.is_eager:
#    3236     try:
# -> 3237       _result = pywrap_tfe.TFE_Py_FastPathExecute(
#    3238         _ctx, "MakeIterator", name, dataset, iterator)
#    3239       return _result
#
# KeyboardInterrupt:
