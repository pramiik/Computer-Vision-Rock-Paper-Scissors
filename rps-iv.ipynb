# %%
import cv2
from keras.models import load_model
import numpy as np
import random
import time
model = load_model('keras_model.h5')

countdown = False
insert = False
ex = True
prt = False
pit = False
stop = False
t_0 = time.time()
timer = 0

cap = cv2.VideoCapture(0)
data = np.ndarray(shape=(1, 224, 224, 3), dtype=np.float32)

final_time = 5

game_options= [ "rock", "paper", "scissors"]

player_points =int()
computer_points =int()
game = int()

wins = str()
finalwins = str()
ds = str()
computer_input = str()
player_input = str()



#t= time.time()
#count =5


def computer():
    global computer_input
    global frame

    computer_input = random.choice(game_options)

    cv2.putText(frame, computer_input, (392, 363), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255),3,cv2.LINE_4)
    cv2.imshow('frame', frame)


    return computer_input

def player():
    computer()
    global player_input
    global timer
    global player_points
    global computer_points
    global game
    global prediction
    global frame


    cv2.putText(frame,'Player vs Computer', (54,426),cv2.FONT_HERSHEY_SIMPLEX, 1.7, (0, 0, 0), 5, cv2.LINE_4)
    cv2.putText (frame,'number of games: ', (25, 25), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255),5)

    #cv2.putText(frame, str(int(timer)), (52,457),cv2.FONT_HERSHEY_SIMPLEX, 1.7, (0, 0, 0), 5, cv2.LINE_4)
    
    rock1 = prediction[0][0] > 0.7
    paper1 = prediction[0][1] > 0.7
    scissors1 = prediction[0][2] > 0.7
    nothing1 = prediction[0][3] > 0.7 

    prediction1=[rock1, paper1, scissors1, nothing1]


    if prediction1[0] == True:
        player_choice = "rock1"
    elif prediction1[1] == True:
        player_choice = "paper1"
    elif prediction1[2] == True:
        player_choice = "scissors1"
    else:
       player_choice = "Try Again"    

    player_input = player_choice

    cv2.putText (frame,player_input, (75, 363), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255),3)

    cv2.imshow('frame', frame)


    return player_input and computer_input


'''

def gameplay():
 

    global computer_input
    global player_input
    global wins
    global insert
    global ex
    global player_points
    global computer_points
    global game
    global timer
    global countdown
    global t_0
    global final_time




    wins = str()
    finalwins = str()

  #  if cv2.waitKey(0) == ord('b'):
   #     timer = time.time() - t_0
    
    if countdown == True and timer > 5:
        ex == False
        timer =0
        
        

        #if countdown == True and ex == False:
        
                    
'''











 


t = time.time()
#layer()
while True:
    
    ret, frame = cap.read()

    #frame = frame[32:, 188:]
    
    resized_frame = cv2.resize(frame, (224, 224), interpolation = cv2.INTER_AREA)
    image_np = np.array(resized_frame)
    normalized_image = (image_np.astype(np.float32) / 127.0) - 1 # Normalize the image
    data[0] = normalized_image
    prediction = model.predict(data)

    cv2.putText(frame,'Player vs Computer', (54,426),cv2.FONT_HERSHEY_SIMPLEX, 1.7, (0, 0, 0), 5, cv2.LINE_4)
    cv2.putText (frame,'number of games: ', (25, 25), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255),5)
    ret, frame = cap.read()
    #t_elapsed = time.time() - t
    #timer = int(5 - round(t_elapsed, 0))

    #player()
    if cv2.waitKey(33) == ord('a'):
        countdown =True
    
    if countdown == True:
        #gameplay()
        timer = time.time() - t_0
        player()
    else:
        t_0 = time.time()
        
    if timer >= 5:

        countdown = False 
        timer = 0

        if (player_input =="paper1" and computer_input == "rock")  or (player_input =="rock1" and computer_input == "scissors")  or (player_input == "scissors1" and computer_input == "paper") :
            print("player wins")    
            wins="player"
            player_points +=1
            game +=1
            next= True
            cv2.putText (frame, "player wins this round", (32, 255), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 0),3)

        elif (player_input == "rock1" and computer_input == "rock")  or (player_input =="paper1" and computer_input== "paper")  or (player_input == "scissors1" and computer_input ==  "scissors") :
            print("Draw")

            game +=1
            ds= "Draw"


            cv2.putText (frame, "draw", (32, 255), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 0),3)

        elif (player_input == "rock1" and computer_input ==  "paper")  or (player_input =="paper1" and computer_input== "scissors")  or (player_input == "scissors1" and computer_input == "rock") :
            print("computer wins")

            wins="computer"

            computer_points +=1
            Next = True
            game +=1
            cv2.putText (frame, "computer wins this round", (32, 255), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 0),3)
            

        else :
            print('try again')

        if next == True:
                    
            if player_points +1:
                cv2.putText (frame, "player wins this round", (32, 255), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 0),3)
                wins="player"
                ex = False
                next = False
                prt = True

            elif computer_points +1:
                cv2.putText (frame, "computer wins this round", (32, 255), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 0),3)
                wins="computer"
                ex = False
                next = False
                prt =True

            else:
                cv2.putText (frame, "draw", (32, 255), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 0),3)
                ds= "Draw"
                countdown = False
                timer = 0
                next = False
                ex = False
                prt = False
                pit =True
                
                


        if ex ==False:

            if player_points==3:

                cv2.putText (frame,("player wins this game! Game Over"),(25,200), cv2.FONT_HERSHEY_SIMPLEX,1,(0,0,0),2)
                insert = True

                finalwins = "Player"
                #time.sleep(10)
                countdown = False
                timer = 0
                stop =True
                


            elif computer_points==3:
                cv2.putText (frame,(" computer wins this game! Game Over"),(25,200), cv2.FONT_HERSHEY_SIMPLEX,1,(0,0,0),2)
                insert = True
                finalwins = "Computer"
                #time.sleep(10)
                countdown = False
                timer = 0
                stop =True
                

            else:
                timer = 0
                countdown = False
                next = False

    cv2.putText(frame, str(final_time - timer ), (100, 100), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 0), 2)

    #if insert == True: #timer > 5:
     #   countdown = False
      #  timer = 0
        #gameplay()

    #cv2.imshow('frame', frame)

        
        #if timer<=0:
            
        
        
    cv2.putText(frame,'Player vs Computer', (54,426),cv2.FONT_HERSHEY_SIMPLEX, 1.7, (0, 0, 0), 5, cv2.LINE_4)
    cv2.putText (frame,'number of games: ', (25, 25), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255),5)
        
    #cv2.putText(frame, computer_input, (392, 363), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255),3,cv2.LINE_4)

    #cv2.putText(frame, str(int(timer)), (117,190),cv2.FONT_HERSHEY_SIMPLEX, 1.7, (0, 0, 0), 5, cv2.LINE_4)
    
    cv2.putText(frame, str(player_points), (117, 471), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255),3)

    cv2.putText (frame, str(computer_points), (445, 471), cv2. FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255),3)
    cv2.putText (frame, str(game), (332, 32), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 0),3)

    cv2.putText (frame,player_input, (75, 363), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255),3)
    cv2.putText(frame, computer_input, (392, 363), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255),3,cv2.LINE_4)
    
    if prt == True:
        word = (wins) +"  " + "wins this round!"
        cv2.putText (frame, word, (32, 255), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 0),3)

    elif pit == True:

        letter = ds+"!" 
        cv2.putText (frame, letter, (32, 255), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 0),3)

    else:
        print("something went wrong :(")

    if insert == True:

        text = finalwins + "wins this game! GAME OVER!!"
        cv2.putText (frame,text,(25,200), cv2.FONT_HERSHEY_SIMPLEX,1,(0,0,0),2)

    else:
        print("something went wrong :(")

    if stop == True:

        cv2.putText (frame, "press button q to restart the game", (32, 145), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 0),3)
        
        if cv2.waitKey(1) & 0xFF == ord('q'):
            game = 0
            player_points = 0
            computer_points = 0
    
    else:
        print ("something went wrong with stop bool :(")





    cv2.imshow('frame', frame)

    #    break  
        
'''



'''
# Out:
# 2022-02-16 15:39:56.284334: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/pramika/miniconda3/envs/rps/lib/python3.9/site-packages/cv2/../../lib64:
# 2022-02-16 15:39:56.284379: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2022-02-16 15:39:58.877275: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/pramika/miniconda3/envs/rps/lib/python3.9/site-packages/cv2/../../lib64:
# 2022-02-16 15:39:58.877346: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-02-16 15:39:58.877387: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (pramika-HP-ENVY-x360-Convertible-13-ar0xxx): /proc/driver/nvidia/version does not exist
# 2022-02-16 15:39:58.878018: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# computer wins
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong :(
# something went wrong with stop bool :(
# player wins
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# computer wins
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# something went wrong :(
# something went wrong with stop bool :(
# computer wins
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_60298/2105206455.py in <module>
#     156     normalized_image = (image_np.astype(np.float32) / 127.0) - 1 # Normalize the image
#     157     data[0] = normalized_image
# --> 158     prediction = model.predict(data)
#     159
#     160     cv2.putText(frame,'Player vs Computer', (54,426),cv2.FONT_HERSHEY_SIMPLEX, 1.7, (0, 0, 0), 5, cv2.LINE_4)
#
# ~/miniconda3/envs/rps/lib/python3.9/site-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~/miniconda3/envs/rps/lib/python3.9/site-packages/keras/engine/training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1756               stacklevel=2)
#    1757
# -> 1758       data_handler = data_adapter.get_data_handler(
#    1759           x=x,
#    1760           batch_size=batch_size,
#
# ~/miniconda3/envs/rps/lib/python3.9/site-packages/keras/engine/data_adapter.py in get_data_handler(*args, **kwargs)
#    1401   if getattr(kwargs["model"], "_cluster_coordinator", None):
#    1402     return _ClusterCoordinatorDataHandler(*args, **kwargs)
# -> 1403   return DataHandler(*args, **kwargs)
#    1404
#    1405
#
# ~/miniconda3/envs/rps/lib/python3.9/site-packages/keras/engine/data_adapter.py in __init__(self, x, y, sample_weight, batch_size, steps_per_epoch, initial_epoch, epochs, shuffle, class_weight, max_queue_size, workers, use_multiprocessing, model, steps_per_execution, distribute)
#    1151
#    1152     adapter_cls = select_data_adapter(x, y)
# -> 1153     self._adapter = adapter_cls(
#    1154         x,
#    1155         y,
#
# ~/miniconda3/envs/rps/lib/python3.9/site-packages/keras/engine/data_adapter.py in __init__(self, x, y, sample_weights, sample_weight_modes, batch_size, epochs, steps, shuffle, **kwargs)
#     323       return flat_dataset
#     324
# --> 325     indices_dataset = indices_dataset.flat_map(slice_batch_indices)
#     326
#     327     dataset = self.slice_inputs(indices_dataset, inputs)
#
# ~/miniconda3/envs/rps/lib/python3.9/site-packages/tensorflow/python/data/ops/dataset_ops.py in flat_map(self, map_func, name)
#    2046       Dataset: A `Dataset`.
#    2047     """
# -> 2048     return FlatMapDataset(self, map_func, name=name)
#    2049
#    2050   def interleave(self,
#
# ~/miniconda3/envs/rps/lib/python3.9/site-packages/tensorflow/python/data/ops/dataset_ops.py in __init__(self, input_dataset, map_func, name)
#    5547     """See `Dataset.flat_map()` for details."""
#    5548     self._input_dataset = input_dataset
# -> 5549     self._map_func = StructuredFunctionWrapper(
#    5550         map_func, self._transformation_name(), dataset=input_dataset)
#    5551     if not isinstance(self._map_func.output_structure, DatasetSpec):
#
# ~/miniconda3/envs/rps/lib/python3.9/site-packages/tensorflow/python/data/ops/dataset_ops.py in __init__(self, func, transformation_name, dataset, input_classes, input_shapes, input_types, input_structure, add_to_graph, use_legacy_function, defun_kwargs)
#    4531         fn_factory = trace_tf_function(defun_kwargs)
#    4532
# -> 4533     self._function = fn_factory()
#    4534     # There is no graph to add in eager mode.
#    4535     add_to_graph &= not context.executing_eagerly()
#
# ~/miniconda3/envs/rps/lib/python3.9/site-packages/tensorflow/python/eager/function.py in get_concrete_function(self, *args, **kwargs)
#    3242          or `tf.Tensor` or `tf.TensorSpec`.
#    3243     """
# -> 3244     graph_function = self._get_concrete_function_garbage_collected(
#    3245         *args, **kwargs)
#    3246     graph_function._garbage_collector.release()  # pylint: disable=protected-access
#
# ~/miniconda3/envs/rps/lib/python3.9/site-packages/tensorflow/python/eager/function.py in _get_concrete_function_garbage_collected(self, *args, **kwargs)
#    3208       args, kwargs = None, None
#    3209     with self._lock:
# -> 3210       graph_function, _ = self._maybe_define_function(args, kwargs)
#    3211       seen_names = set()
#    3212       captured = object_identity.ObjectIdentitySet(
#
# ~/miniconda3/envs/rps/lib/python3.9/site-packages/tensorflow/python/eager/function.py in _maybe_define_function(self, args, kwargs)
#    3555
#    3556           self._function_cache.missed.add(call_context_key)
# -> 3557           graph_function = self._create_graph_function(args, kwargs)
#    3558           self._function_cache.primary[cache_key] = graph_function
#    3559
#
# ~/miniconda3/envs/rps/lib/python3.9/site-packages/tensorflow/python/eager/function.py in _create_graph_function(self, args, kwargs, override_flat_arg_shapes)
#    3390     arg_names = base_arg_names + missing_arg_names
#    3391     graph_function = ConcreteFunction(
# -> 3392         func_graph_module.func_graph_from_py_func(
#    3393             self._name,
#    3394             self._python_function,
#
# ~/miniconda3/envs/rps/lib/python3.9/site-packages/tensorflow/python/framework/func_graph.py in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, override_flat_arg_shapes, acd_record_initial_resource_uses)
#    1141         _, original_func = tf_decorator.unwrap(python_func)
#    1142
# -> 1143       func_outputs = python_func(*func_args, **func_kwargs)
#    1144
#    1145       # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#
# ~/miniconda3/envs/rps/lib/python3.9/site-packages/tensorflow/python/data/ops/dataset_ops.py in wrapped_fn(*args)
#    4508           attributes=defun_kwargs)
#    4509       def wrapped_fn(*args):  # pylint: disable=missing-docstring
# -> 4510         ret = wrapper_helper(*args)
#    4511         ret = structure.to_tensor_list(self._output_structure, ret)
#    4512         return [ops.convert_to_tensor(t) for t in ret]
#
# ~/miniconda3/envs/rps/lib/python3.9/site-packages/tensorflow/python/data/ops/dataset_ops.py in wrapper_helper(*args)
#    4438       if not _should_unpack(nested_args):
#    4439         nested_args = (nested_args,)
# -> 4440       ret = autograph.tf_convert(self._func, ag_ctx)(*nested_args)
#    4441       if _should_pack(ret):
#    4442         ret = tuple(ret)
#
# ~/miniconda3/envs/rps/lib/python3.9/site-packages/tensorflow/python/autograph/impl/api.py in wrapper(*args, **kwargs)
#     694       try:
#     695         with conversion_ctx:
# --> 696           return converted_call(f, args, kwargs, options=options)
#     697       except Exception as e:  # pylint:disable=broad-except
#     698         if hasattr(e, 'ag_error_metadata'):
#
# ~/miniconda3/envs/rps/lib/python3.9/site-packages/tensorflow/python/autograph/impl/api.py in converted_call(f, args, kwargs, caller_fn_scope, options)
#     381
#     382   if not options.user_requested and conversion.is_allowlisted(f):
# --> 383     return _call_unconverted(f, args, kwargs, options)
#     384
#     385   # internal_convert_user_code is for example turned off when issuing a dynamic
#
# ~/miniconda3/envs/rps/lib/python3.9/site-packages/tensorflow/python/autograph/impl/api.py in _call_unconverted(f, args, kwargs, options, update_cache)
#     462
#     463   if kwargs is not None:
# --> 464     return f(*args, **kwargs)
#     465   return f(*args)
#     466
#
# ~/miniconda3/envs/rps/lib/python3.9/site-packages/keras/engine/data_adapter.py in slice_batch_indices(indices)
#     308       """
#     309       num_in_full_batch = num_full_batches * batch_size
# --> 310       first_k_indices = tf.slice(indices, [0], [num_in_full_batch])
#     311       first_k_indices = tf.reshape(
#     312           first_k_indices, [num_full_batches, batch_size])
#
# ~/miniconda3/envs/rps/lib/python3.9/site-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~/miniconda3/envs/rps/lib/python3.9/site-packages/tensorflow/python/util/dispatch.py in op_dispatch_handler(*args, **kwargs)
#    1094       # Fallback dispatch system (dispatch v1):
#    1095       try:
# -> 1096         return dispatch_target(*args, **kwargs)
#    1097       except (TypeError, ValueError):
#    1098         # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# ~/miniconda3/envs/rps/lib/python3.9/site-packages/tensorflow/python/ops/array_ops.py in slice(input_, begin, size, name)
#    1107     A `Tensor` the same type as `input_`.
#    1108   """
# -> 1109   return gen_array_ops._slice(input_, begin, size, name=name)
#    1110
#    1111
#
# ~/miniconda3/envs/rps/lib/python3.9/site-packages/tensorflow/python/ops/gen_array_ops.py in _slice(input, begin, size, name)
#    9583         "Slice", input=input, begin=begin, size=size, name=name)
#    9584   _result = _outputs[:]
# -> 9585   if _execute.must_record_gradient():
#    9586     _attrs = ("T", _op._get_attr_type("T"), "Index",
#    9587               _op._get_attr_type("Index"))
#
# ~/miniconda3/envs/rps/lib/python3.9/site-packages/tensorflow/python/eager/backprop.py in _must_record_gradient()
#     165
#     166
# --> 167 def _must_record_gradient():
#     168   return not pywrap_tfe.TFE_Py_TapeSetIsEmpty()
#     169
#
# KeyboardInterrupt:
