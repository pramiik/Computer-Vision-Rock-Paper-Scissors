# %%
import cv2
from keras.models import load_model
import numpy as np
import random 
import time
model = load_model('keras_model.h5')
cap = cv2.VideoCapture(0)
data = np.ndarray(shape=(1, 224, 224, 3), dtype=np.float32)
player_points = 0

t=3
def countdown(t):
    while t:
        mins, secs = divmod(t, 60)
        timer = '{:02d}'.format(secs)
        print(timer, end="\r")
        t -= 1


def player_choice_game():

    

    rock1 = prediction[0][0] > 0.7
    paper1 = prediction[0][1] > 0.7
    scissors1 = prediction[0][2] > 0.7
    nothing1 = prediction[0][3] > 0.7 

    prediction1=[rock1, paper1, scissors1, nothing1]


    if prediction1[0][0] == True:
        player_choice = 'rock1'
    elif prediction1[0][1] == True:
        player_choice = 'paper1'
    elif prediction1[0][2] == True:
        player_choice = 'scissors1'
    else:
        player_choice = 'nothing1'    

    player_input = player_choice

    print (f" player's choice is {player_input}")

    #countdown(int(t))

    cv2.putText(frame,countdown(str(t)), (5,455),cv2.FONT_HERSHEY_SIMPLEX, 1.7, (0, 0, 0),5, cv2.LINE_4)

    cv2.putText (frame,player_input, (5, 455), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 255))

    player_points =0
    
    if (player_input =='paper1' and computer_input == 'rock')  or (player_input =='rock1' and computer_input == 'scissors')  or (player_input == 'scissors1' and computer_input == 'paper') :
        print('player wins')    
        player_points +=1

    elif (player_input == 'rock1' and computer_input == 'rock')  or (player_input =='paper1' and computer_input== 'paper')  or (player_input == 'scissors1' and computer_input ==  'scissors') :
        print('Draw')

    elif (player_input == 'rock1' and computer_input ==  'paper')  or (player_input =='paper1' and computer_input== 'scissors')  or (player_input == 'scissors1' and computer_input == 'rock') :
        print('computer wins')
        

    else :
        print('try again')



game_options= [ 'rock', 'paper', 'scissors']
computer_input = random.choice(game_options)
  
print (f" computer's choice is {computer_input}")

while True: 
    ret, frame = cap.read()
    cv2.putText(frame,'Player vs Computer', (52,457),cv2.FONT_HERSHEY_SIMPLEX, 1.7, (0, 0, 0), 5, cv2.LINE_4)
    resized_frame = cv2.resize(frame, (224, 224), interpolation = cv2.INTER_AREA)
    image_np = np.array(resized_frame)
    normalized_image = (image_np.astype(np.float32) / 127.0) - 1 # Normalize the image
    data[0] = normalized_image
    prediction = model.predict(data)
    cv2.imshow('frame', frame)
    player =0

    player_choice_game()

    # Press q to close the window
    #print(prediction)

   


    if cv2.waitKey(1) & 0xFF == ord('q'):
        break



'''       
def countdown():

    counter = 4

    while True:
        time.sleep(1)
        counter-=1 
        print(counter)
    cv2.putText(frame,countdown(), (255,255),cv2.FONT_HERSHEY_SIMPLEX, 1.7, (0, 0, 0), 5, cv2.LINE_4)

# After the loop release the cap object
cap.release()
# Destroy all the windows
cv2.destroyAllWindows()
'''

'''

https://github.com/pramiik/practice_repo_lessons.git

https://github.com/pramiik/practice_repo_lessons.git
https://github.com/pramiik/Computer-Vision-Rock-Paper-Scissors.git
'''
# Out:
# 2022-02-08 19:15:35.072533: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/pramika/miniconda3/envs/rps/lib/python3.9/site-packages/cv2/../../lib64:
# 2022-02-08 19:15:35.072691: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2022-02-08 19:15:40.708869: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/pramika/miniconda3/envs/rps/lib/python3.9/site-packages/cv2/../../lib64:
# 2022-02-08 19:15:40.708943: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-02-08 19:15:40.708985: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (pramika-HP-ENVY-x360-Convertible-13-ar0xxx): /proc/driver/nvidia/version does not exist
# 2022-02-08 19:15:40.709889: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
#  computer's choice is scissors
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_3841/2947351505.py in <module>
#      83     player =0
#      84
# ---> 85     player_choice_game()
#      86
#      87     # Press q to close the window
#
# /tmp/ipykernel_3841/2947351505.py in player_choice_game()
#      30
#      31
# ---> 32     if prediction1[0][0] == True:
#      33         player_choice = 'rock1'
#      34     elif prediction1[0][1] == True:
#
# IndexError: invalid index to scalar variable.
