# %%
import cv2
from keras.models import load_model
import numpy as np
import random 
import time
import sys
model = load_model('keras_model.h5')
cap = cv2.VideoCapture(0)
data = np.ndarray(shape=(1, 224, 224, 3), dtype=np.float32)
player_points = int()
computer_points =int()
game =int()

'''
t=3
def countdown(t):
    while t:
        mins, secs = divmod(t, 60)
        timer = '{:02d}'.format(secs)
        print(timer, end="\r")
        t -= 1

'''
game_options= [ "rock", "paper", "scissors"]

def countdown(cap):
    
    computer_input = random.choice(game_options)
    t = time.time()
    cap = cv2.VideoCapture(0)
    #print (f" computer's choice is {computer_input}")
    count=5
    while count: #in range(5):


    
        cv2.putText(frame, computer_input, (392, 363), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255),3,cv2.LINE_4)

        rock1 = prediction[0][0] > 0.7
        paper1 = prediction[0][1] > 0.7
        scissors1 = prediction[0][2] > 0.7
        nothing1 = prediction[0][3] > 0.7 

        prediction1=[rock1, paper1, scissors1, nothing1]


        if prediction1[0] == True:
            player_choice = "rock1"
        elif prediction1[1] == True:
            player_choice = "paper1"
        elif prediction1[2] == True:
            player_choice = "scissors1"
        else:
            player_choice = "Try Again"    

        ret, frame = cap.read()
        t_elapsed = time.time() - t
        timer = int(count - round(t_elapsed, 0))
        if timer == 0:
            t = time.time()
        cv2.putText(frame, str(timer), (52,457),cv2.FONT_HERSHEY_SIMPLEX, 1.7, (0, 0, 0), 5, cv2.LINE_4)
        #cv2.imshow('frame', frame)


        #print (f" player's choice is {player_input}")


    
    player_input = player_choice

    #cv2.putText(frame,(timer), (250,250),cv2.FONT_HERSHEY_SIMPLEX, 1.7, (0, 0, 0),5, cv2.LINE_4)

    #cv2.putText(frame,'player:', (25, 410), cv2. FONT_HERSHEY_SIMPLEX, 1, (0, 255, 255))
    cv2.putText (frame,player_input, (75, 363), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255),3)

    

    global player_points 
    global computer_points
    global game 
    
    
    if (player_input =="paper1" and computer_input == "rock")  or (player_input =="rock1" and computer_input == "scissors")  or (player_input == "scissors1" and computer_input == "paper") :
        print("player wins")    
        player_points +=1
        game +=1

    elif (player_input == "rock1" and computer_input == "rock")  or (player_input =="paper1" and computer_input== "paper")  or (player_input == "scissors1" and computer_input ==  "scissors") :
        print("Draw")
        game +=1

    elif (player_input == "rock1" and computer_input ==  "paper")  or (player_input =="paper1" and computer_input== "scissors")  or (player_input == "scissors1" and computer_input == "rock") :
        print("computer wins")
        computer_points +=1
        game +=1
        

    else :
        print('try again')



    cv2.putText(frame, str(player_points), (117, 471), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255),3)

    cv2.putText (frame, str(computer_points), (445, 471), cv2. FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255),3)
    

    cv2.putText (frame, str(game), (332, 32), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 0),3)

    #cv2.waitKey(1) == ord('e')

    #print(f"computer points is {type(computer_points)}")
    #print(f"player point is {type(player_points)}")
    #print(f"game: {type(game)}")




while True: 
    ret, frame = cap.read()
    resized_frame = cv2.resize(frame, (224, 224), interpolation = cv2.INTER_AREA)
    image_np = np.array(resized_frame)
    normalized_image = (image_np.astype(np.float32) / 127.0) - 1 # Normalize the image
    data[0] = normalized_image
    prediction = model.predict(data)

    cv2.putText(frame,'Player vs Computer', (54,426),cv2.FONT_HERSHEY_SIMPLEX, 1.7, (0, 0, 0), 5, cv2.LINE_4)

    #cv2.putText (frame,'Computer: ', (300, 418), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 255),5, cv2.LINE_4)
    #cv2.putText(frame, 'player points:',(25, 380), cv2. FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255))
    #cv2.putText(frame, 'computer points: ', (25, 325), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255))
    cv2.putText (frame,'number of games: ', (25, 25), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255),5)




    countdown()


    cv2.imshow('frame', frame)
    



    # Press q to close the window
    #print(prediction)


    if cv2.waitKey(1) & 0xFF == ord('q'):
        break



'''       
def countdown():

    counter = 4

    while True:
        time.sleep(1)
        counter-=1 
        print(counter)
    cv2.putText(frame,countdown(), (255,255),cv2.FONT_HERSHEY_SIMPLEX, 1.7, (0, 0, 0), 5, cv2.LINE_4)

# After the loop release the cap object
cap.release()
# Destroy all the windows
cv2.destroyAllWindows()
'''

'''

https://github.com/pramiik/practice_repo_lessons.git

https://github.com/pramiik/practice_repo_lessons.git
https://github.com/pramiik/Computer-Vision-Rock-Paper-Scissors.git
'''
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# [ WARN:0@157.141] global /io/opencv/modules/videoio/src/cap_v4l.cpp (889) open VIDEOIO(V4L2:/dev/video0): can't open camera by index
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# /tmp/ipykernel_6633/717087766.py in <module>
#     119 while True:
#     120     ret, frame = cap.read()
# --> 121     resized_frame = cv2.resize(frame, (224, 224), interpolation = cv2.INTER_AREA)
#     122     image_np = np.array(resized_frame)
#     123     normalized_image = (image_np.astype(np.float32) / 127.0) - 1 # Normalize the image
#
# error: OpenCV(4.5.5) /io/opencv/modules/imgproc/src/resize.cpp:4052: error: (-215:Assertion failed) !ssize.empty() in function 'resize'

# %%
# Out:
# 2022-02-11 19:59:03.817771: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/pramika/miniconda3/envs/rps/lib/python3.9/site-packages/cv2/../../lib64:
# 2022-02-11 19:59:03.817813: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2022-02-11 19:59:06.886905: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/pramika/miniconda3/envs/rps/lib/python3.9/site-packages/cv2/../../lib64:
# 2022-02-11 19:59:06.886965: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-02-11 19:59:06.887004: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (pramika-HP-ENVY-x360-Convertible-13-ar0xxx): /proc/driver/nvidia/version does not exist
# 2022-02-11 19:59:06.887443: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# [ WARN:0@10.101] global /io/opencv/modules/videoio/src/cap_v4l.cpp (889) open VIDEOIO(V4L2:/dev/video0): can't open camera by index
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# /tmp/ipykernel_3459/4094123793.py in <module>
#      33 while True:
#      34     ret, frame = cap.read()
# ---> 35     resized_frame = cv2.resize(frame, (224, 224), interpolation = cv2.INTER_AREA)
#      36     image_np = np.array(resized_frame)
#      37     normalized_image = (image_np.astype(np.float32) / 127.0) - 1 # Normalize the image
#
# error: OpenCV(4.5.5) /io/opencv/modules/imgproc/src/resize.cpp:4052: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
